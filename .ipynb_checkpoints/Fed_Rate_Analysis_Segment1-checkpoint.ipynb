# %%
# pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.9.5.tar.gz (384 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/helengarcia/opt/anaconda3/envs/mlenv/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/hs/x4cx8mr57cq5h2r45l844wj00000gn/T/pip-install-no6jbqki/psycopg2_d31f0775366d47068a94f235f46fa2dd/setup.py'"'"'; __file__='"'"'/private/var/folders/hs/x4cx8mr57cq5h2r45l844wj00000gn/T/pip-install-no6jbqki/psycopg2_d31f0775366d47068a94f235f46fa2dd/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/hs/x4cx8mr57cq5h2r45l844wj00000gn/T/pip-pip-egg-info-c8tk4mqg
# ...

# %%
import sys, os
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
import psycopg2

conn = psycopg2.connect(database="Unemployment_db",
                        host="127.0.0.1",
                        user="helengarcia3",
                        password="db_password",
                        port="5432")

# db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Unemployment_db"
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /var/folders/hs/x4cx8mr57cq5h2r45l844wj00000gn/T/ipykernel_84530/668413833.py in <module>
#       5                         user="helengarcia3",
#       6                         password="db_password",
# ----> 7                         port="5432")
#       8
#       9 # db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Unemployment_db"
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  password authentication failed for user "helengarcia3"

# %%
# Multivariate Regression - all five features for X & Unemployment Rate for y

# %%
# Import Modules & Create Database Engine
from sqlalchemy import create_engine
from config import db_password
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Unemployment_db"
engine = create_engine(db_string)

# %%
unemployment_df.to_sql(name='unemployment_table', con=engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 db_string.to_sql(name='unemployment_table', con=engine)
#
# AttributeError: 'str' object has no attribute 'to_sql'

# %%
# Transform and merge the ratings DataFrame
# create the connection to the PostgreSQL database

    db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/movie_data"
    
    
    # Create the database engine (to the PostgreSQL database)
    engine = create_engine(db_string)
    
    # Import the movies_df DataFrame to a SQL database.
    movies_df.to_sql(name='movies', if_exists='replace',con=engine)
    
    # Create a variable rows_imported
    rows_imported = 0
    
    # Set start_time from time.time()
    start_time = time.time()

    for data in pd.read_csv(f'{file_dir}/ratings.csv', chunksize=1000000):

        # Print out the range of rows
        print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')

        data.to_sql(name='ratings', con=engine, if_exists='append')

        # Increment the numb. rows imported
        rows_imported += len(data)

        # Final print out
        print(f'Done. {time.time() - start_time} total seconds elapsed')
